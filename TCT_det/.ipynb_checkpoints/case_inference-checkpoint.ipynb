# %%
import openslide
from itertools import product
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os

import tensorflow as tf
import torch
from tensorflow.python.platform import gfile
import os
import json
from tqdm import tqdm_notebook

import numpy as np
# %matplotlib inline
from glob import glob

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd
import cv2
import torch.utils.data as data
from glob import glob
from random import shuffle
from PIL import Image
import random
from tqdm import tqdm
from skimage.io import imread,imsave
import random

os.environ['CUDA_VISIBLE_DEVICES'] = '2'
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import resnet
model_ft = resnet.resnet18(pretrained =True)
model_ft.fc = nn.Linear(model_ft.fc.in_features, 2)
# model_ft.avgpool = nn.AdaptiveMaxPool2d(output_size=(1,1))
# model_ft = nn.Sequential(
#     model_ft,
#     nn.Softmax(dim=-1)
# )
model_ft.load_state_dict(torch.load("/hdd/sd5/tlc/TCT/Model_pth/DAN_network_weight.pth"))
#model_ft.load_state_dict(torch.load("/hdd/sd2/data/TCT/densenet/model/0812_5_folder_noascus大图小图/final_model/resnet18_v1.pth"))
# model_ft.load_state_dict(torch.load("/hdd/sd2/data/TCT/densenet/model/0806_all_data_5fold_data/final_model/resnet18_v3_more_YFY_neg_less_HSV.pth"))
model_ft.cuda()
model_ft = model_ft.eval()
model = model_ft

# %%
def img_resize(image, target_size):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    ih, iw    = target_size
    h,  w, _  = image.shape

    scale = min(float(iw)/w, float(ih)/h)
    nw, nh  = int(scale * w), int(scale * h)
    try:
        image_resized = cv2.resize(image, (nw, nh), interpolation=0)
    except Exception as e:
        print (str(e))
        
    image_paded = np.full(shape=[ih, iw, 3], fill_value=0)
    dw, dh = (iw - nw) // 2, (ih-nh) // 2
    image_paded[dh:nh+dh, dw:nw+dw, :] = image_resized
    return image_paded

def postprocess_boxes(pred_bbox, org_img_shape, input_size, score_threshold):
    valid_scale=[0, np.inf]
    
    pred_bbox = np.array(pred_bbox)
    #print (pred_bbox.shape)
    pred_xywh = pred_bbox[:, 0:4]
    pred_conf = pred_bbox[:, 4]
    pred_prob = pred_bbox[:, 5:]
    # # (1) (x, y, w, h) --> (xmin, ymin, xmax, ymax)
    pred_coor = np.concatenate([pred_xywh[:, :2] - pred_xywh[:, 2:] * 0.5,
                                pred_xywh[:, :2] + pred_xywh[:, 2:] * 0.5], axis=-1)
    # # (2) (xmin, ymin, xmax, ymax) -> (xmin_org, ymin_org, xmax_org, ymax_org)
    org_h, org_w = org_img_shape
    resize_ratio = min(float(input_size) / org_w, float(input_size) / org_h)

    dw = (input_size - resize_ratio * org_w) / 2
    dh = (input_size - resize_ratio * org_h) / 2

    pred_coor[:, 0::2] = 1.0 * (pred_coor[:, 0::2] - dw) / resize_ratio
    pred_coor[:, 1::2] = 1.0 * (pred_coor[:, 1::2] - dh) / resize_ratio

    # # (3) clip some boxes those are out of range
    pred_coor = np.concatenate([np.maximum(pred_coor[:, :2], [0, 0]),
                                np.minimum(pred_coor[:, 2:], [org_w - 1, org_h - 1])], axis=-1)
    invalid_mask = np.logical_or((pred_coor[:, 0] > pred_coor[:, 2]), (pred_coor[:, 1] > pred_coor[:, 3]))
    pred_coor[invalid_mask] = 0
    

    # # (4) discard some invalid boxes
    bboxes_scale = np.sqrt(np.multiply.reduce(pred_coor[:, 2:4] - pred_coor[:, 0:2], axis=-1))
    scale_mask = np.logical_and((valid_scale[0] < bboxes_scale), (bboxes_scale < valid_scale[1]))
    #print np.where(scale_mask is True)

    # # (5) discard some boxes with low scores
    classes = np.argmax(pred_prob, axis=-1)
    scores = pred_conf * pred_prob[np.arange(len(pred_coor)), classes]
    #print (np.max(scores))
    score_mask = scores > score_threshold
    #print np.sum(score_mask)
    mask = np.logical_and(scale_mask, score_mask)
    coors, scores, classes = pred_coor[mask], scores[mask], classes[mask]

    return np.concatenate([coors, scores[:, np.newaxis], classes[:, np.newaxis]], axis=-1)

def bboxes_iou(boxes1, boxes2):

    boxes1 = np.array(boxes1)
    boxes2 = np.array(boxes2)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up       = np.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down    = np.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = np.maximum(right_down - left_up, 0.0)
    inter_area    = inter_section[..., 0] * inter_section[..., 1]
    union_area    = boxes1_area + boxes2_area - inter_area
    ious          = np.maximum(1.0 * inter_area / union_area, np.finfo(np.float32).eps)

    return ious

def nms(bboxes, iou_threshold, sigma=0.3, method='nms'):
    """
    :param bboxes: (xmin, ymin, xmax, ymax, score, class)

    Note: soft-nms, https://arxiv.org/pdf/1704.04503.pdf
          https://github.com/bharatsingh430/soft-nms
    """
    classes_in_img = list(set(bboxes[:, 5]))
    best_bboxes = []

    for cls in classes_in_img:
        cls_mask = (bboxes[:, 5] == cls)
        cls_bboxes = bboxes[cls_mask]

        while len(cls_bboxes) > 0:
            max_ind = np.argmax(cls_bboxes[:, 4])
            best_bbox = cls_bboxes[max_ind]
            best_bboxes.append(best_bbox)
            cls_bboxes = np.concatenate([cls_bboxes[: max_ind], cls_bboxes[max_ind + 1:]])
            iou = bboxes_iou(best_bbox[np.newaxis, :4], cls_bboxes[:, :4])
            weight = np.ones((len(iou),), dtype=np.float32)

            assert method in ['nms', 'soft-nms']
            if method == 'nms':
                iou_mask = iou > iou_threshold
                weight[iou_mask] = 0.0

            if method == 'soft-nms':
                weight = np.exp(-(1.0 * iou ** 2 / sigma))

            cls_bboxes[:, 4] = cls_bboxes[:, 4] * weight
            score_mask = cls_bboxes[:, 4] > 0.
            cls_bboxes = cls_bboxes[score_mask]

    return best_bboxes

# %%
# test_path = glob("/hdd/sd5/tlc/TCT/all_data/YFY_20200305/data/test/pos/*")
# test_path = glob("/ssd2/yuyue/TCT_data/ori_data/YFY_data/val/pos/*")
# test_path = glob("/hdd/sd5/tlc/TCT/all_data/20190717/val/pos/*")neg
test_path = glob("/fileser/yuyue/TCT_data/ori_data/QL_YT_data/train/neg/*")
# test_path = torch.load("/hdd/sd2/YFY新增33标注路径.pth")
len(test_path)
# Out:
# 30

# %%
cls_path = []
with tf.Graph().as_default() as graph:
    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    with tf.Session(graph=graph,config=config) as sess:
        tf.global_variables_initializer().run()
        #with gfile.FastGFile("/hdd/sd2/data/TCT/yolo/model/0817_三分类/yolov3_test_loss=6.0245.pb", 'rb') as f:
        with gfile.FastGFile("/hdd/sd5/tlc/TCT/Model_pb/ghm_loss/yolov3_test_loss=7.5190.pb", 'rb') as f:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(f.read())
            tf.import_graph_def(graph_def, name='') # 导入计算图
            input_ = sess.graph.get_tensor_by_name('input_data:0')
            trainable_ = sess.graph.get_tensor_by_name('training:0')
            op_sbbox = sess.graph.get_tensor_by_name('pred_sbbox/op_to_store:0')
            op_mbbox = sess.graph.get_tensor_by_name('pred_mbbox/op_to_store:0')
            op_lbbox = sess.graph.get_tensor_by_name('pred_lbbox/op_to_store:0')
            
            coord_dict = {}

            for folder in test_path:
                folder_name = folder.split("/")[-1]
                count = 0
                count_cls = 0
                
                coord_dict[folder_name] = {}
                
                for i in tqdm_notebook(glob(folder+"/*")):
                    img_name = folder_name+"_"+i.split("/")[-1].split(".")[0]
                    try:
                        img = cv2.imread(i)
                        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                        img = cv2.resize(img, (224*3, 224*2))
                    except:
                        continue

                    img1 = img[0:224,0:224]
                    img2 = img[0:224,224:224*2]
                    img3 = img[0:224,224*2:224*3]
                    img4 = img[224:224*2,0:224]
                    img5 = img[224:224*2,224:224*2]
                    img6 = img[224:224*2,224*2:224*3]

                    coord_dict[folder_name][i] = []
                    for idx,n in enumerate([img1,img2,img3,img4,img5,img6]):
#                     for idx,n in enumerate([img2]):
                        detect_flag = False
#                         n = cv2.cvtColor(n, cv2.COLOR_BGR2RGB)
                        img_totensor = transforms.ToTensor()(n)
#                         img_totensor = transforms.Normalize(mean,std)(img_totensor)
                        input_img = img_totensor.unsqueeze(0)
                        input_img = Variable(input_img.cuda())

                        
                        outputs,_ = model(input_img, 1)

#                         _, preds = torch.max(outputs.data, 1)
                        outputs = list(outputs.cpu().data.numpy())
                        if outputs[0][1] > 0.5:
                            cls_score = outputs[0][1]
#                             CAMs = cam.data.cpu().squeeze().numpy()
#                             CAMs = cv2.resize(CAMs,(224,224))
                            cls_path.append([i,idx])
                            detect_flag = True
                            count_cls += 1
                    
                        if detect_flag:
                            n = cv2.cvtColor(n, cv2.COLOR_BGR2RGB)
                            image_norm = n/255.
                            input_img = image_norm[np.newaxis, ...]
                            pred_sbbox, pred_mbbox, pred_lbbox = sess.run([op_sbbox, op_mbbox, op_lbbox], feed_dict={input_:input_img,trainable_:False})
#                             print(pred_sbbox.shape)
                            
                            pred_bbox = np.concatenate([np.reshape(pred_sbbox, (-1, 5 + 2)),
                                                        np.reshape(pred_mbbox, (-1, 5 + 2)),
                                                        np.reshape(pred_lbbox, (-1, 5 + 2))], axis=0)
                            bboxes = postprocess_boxes(pred_bbox, (224, 224), 224, 0.3)
                            bboxes_pr = nms(bboxes, 0.3)
                            
                            if len(bboxes_pr) > 0:
                                for bbox in bboxes_pr:
                                    coor = np.array(bbox[:4], dtype=np.int32)
                                    prob_yolo = np.array(bbox[4])
                                    cls = bbox[5]

                                    c1 = (coor[0],coor[1])
                                    c2 = (coor[2],coor[3])

                                    count += 1
                                    coord_dict[folder_name][i].append([c1,c2,idx,prob_yolo,cls_score,cls])  

                print("pos num: ",count,count_cls)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# pos num:  16 15
# ...
# pos num:  9 13
# ...
# pos num:  4 4
# ...
# pos num:  116 110
# ...
# pos num:  15 16
# ...
# pos num:  23 23
# ...
# pos num:  79 88
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7b8f1f3574ae> in <module>
#      25                 coord_dict[folder_name] = {}
#      26
# ---> 27                 for i in tqdm_notebook(glob(folder+"/*")):
#      28                     img_name = folder_name+"_"+i.split("/")[-1].split(".")[0]
#      29                     try:
#
# /opt/miniconda3/lib/python3.7/site-packages/tqdm/notebook.py in __iter__(self, *args, **kwargs)
#     216     def __iter__(self, *args, **kwargs):
#     217         try:
# ...

# %%
test_path = glob("/fileser/yuyue/TCT_data/ori_data/QL_YT_data/train/pos/*")
len(test_path)
# Out:
# 10

# %%
cls_path = []
# slide_path = "/fileser/yuyue/wholeSvs/val/pos/YFY/1ae0ef92f76897397c6245e196b3e6ab5b1ea2f6.svs"
# slide = openslide.OpenSlide(slide_path)
# slide_name = slide_path.split("/")[-1].split(".")[0]


with tf.Graph().as_default() as graph:
    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    with tf.Session(graph=graph,config=config) as sess:
        tf.global_variables_initializer().run()
        with gfile.FastGFile("/hdd/sd5/tlc/TCT/Model_pb/ghm_loss/yolov3_test_loss=7.5190.pb", 'rb') as f:
#         with gfile.FastGFile("/hdd/sd2/data/TCT/yolo/model/0811_单细胞成团分类/yolov3_test_loss=5.4237.pb", 'rb') as f:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(f.read())
            tf.import_graph_def(graph_def, name='') # 导入计算图
            input_ = sess.graph.get_tensor_by_name('input_data:0')
            trainable_ = sess.graph.get_tensor_by_name('training:0')
            op_sbbox = sess.graph.get_tensor_by_name('pred_sbbox/op_to_store:0')
            op_mbbox = sess.graph.get_tensor_by_name('pred_mbbox/op_to_store:0')
            op_lbbox = sess.graph.get_tensor_by_name('pred_lbbox/op_to_store:0')
            
            coord_dict = {}
            for uid_path in test_path:
                slide_path = glob(uid_path+'/*.svs')[0]
                slide = openslide.OpenSlide(slide_path)
                slide_name = slide_path.split("/")[-1].split(".")[0]
                coord_dict[slide_name] = {}
                count = 0
                count_cls = 0
                for i in tqdm_notebook(range(slide.level_dimensions[0][0]//1936)):
                    for j in range(slide.level_dimensions[0][1]//1216):
                        x = i*1936
                        y = j*1216
                        img = slide.read_region((x,y),0,(1936,1216)).convert("RGB")
                        img = np.array(img)
                        img = cv2.resize(img, (224*3, 224*2))
                        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                        img1 = img[0:224,0:224]
                        img2 = img[0:224,224:224*2]
                        img3 = img[0:224,224*2:224*3]
                        img4 = img[224:224*2,0:224]
                        img5 = img[224:224*2,224:224*2]
                        img6 = img[224:224*2,224*2:224*3]

                        coord_dict[slide_name][(x,y)] = []


                        for idx,n in enumerate([img1,img2,img3,img4,img5,img6]):
                            detect_flag = False
                            img_totensor = transforms.ToTensor()(n)
                            input_img = img_totensor.unsqueeze(0)
                            input_img = Variable(input_img.cuda())

                            outputs,_ = model(input_img, 1.0)
                            _, preds = torch.max(outputs.data, 1)
                            outputs = list(outputs.cpu().data.numpy())
                            if outputs[0][1] > 0.7:
                                cls_score = outputs[0][1]
                                count_cls += 1
    #                             CAMs = cam.data.cpu().squeeze().numpy()
    #                             CAMs = cv2.resize(CAMs,(224,224))
                                detect_flag = True

                            if detect_flag:
                                #n = cv2.cvtColor(n, cv2.COLOR_BGR2RGB)
                                image_norm = n/255.
                                input_img = image_norm[np.newaxis, ...]
                                pred_sbbox, pred_mbbox, pred_lbbox = sess.run([op_sbbox, op_mbbox, op_lbbox], feed_dict={input_:input_img,trainable_:False})
                                pred_bbox = np.concatenate([np.reshape(pred_sbbox, (-1, 5 + 2)),
                                                            np.reshape(pred_mbbox, (-1, 5 + 2)),
                                                            np.reshape(pred_lbbox, (-1, 5 + 2))], axis=0)
                                bboxes = postprocess_boxes(pred_bbox, (224, 224), 224, 0.3)
                                bboxes_pr = nms(bboxes, 0.1)

                                if len(bboxes_pr) > 0:
                                    for bbox in bboxes_pr:
                                        coor = np.array(bbox[:4], dtype=np.int32)
                                        prob_yolo = np.array(bbox[4])
                                        cls = bbox[5]

                                        c1 = (coor[0],coor[1])
                                        c2 = (coor[2],coor[3])

                                        count += 1
                                        coord_dict[slide_name][(x,y)].append([c1,c2,idx,prob_yolo,cls_score,cls])


                print("pos num: ",count, count_cls)
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# /opt/miniconda3/lib/python3.7/site-packages/torch/nn/functional.py:2751: UserWarning: Default grid_sample and affine_grid behavior will be changed to align_corners=False from 1.4.0. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior will be changed "
# /opt/miniconda3/lib/python3.7/site-packages/torch/nn/functional.py:2693: UserWarning: Default grid_sample and affine_grid behavior will be changed to align_corners=False from 1.4.0. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior will be changed "
# pos num:  266 448
# ...
# pos num:  250 283
# ...
# ---------------------------------------------------------------------------
# ...

# %%
final_results = {}
for i in coord_dict.keys():
    final_results[i] = {}
    dic = coord_dict[i]
    temp_list_LSIL = []
    temp_list_HSIL = []
    for j in dic.keys():
        if len(dic[j]) > 0:
            for info in dic[j]:
                prob = (info[3]+info[4])/2
                if int(info[5]) == 0:
                    temp_list_LSIL.append([j,info,prob])
                else:
                    temp_list_HSIL.append([j,info,prob])

    sort_list_LSIL = sorted(temp_list_LSIL,key = lambda x:x[2],reverse=True)
    sort_list_HSIL = sorted(temp_list_HSIL,key = lambda x:x[2],reverse=True)
    final_results[i]["sort_list_LSIL"] = sort_list_LSIL
    final_results[i]["sort_list_HSIL"] = sort_list_HSIL

# %%
coord_dict.keys()
# Out:
# dict_keys(['2020-08-05-165840'])

# %%
final_results.keys()
# Out:
# dict_keys(['2020-07-21-094821', '2020-07-23-090416', '2020-07-15-164752', '2020-07-17-150719', '2020-07-29-091752', '2020-07-28-165233'])

# %%
for slide_name in final_results.keys():
    for i in final_results[slide_name]["sort_list_LSIL"][0:10]+final_results[slide_name]["sort_list_HSIL"][0:10]:
        path,info,prob = i
        print(prob,path)
        img_ori = np.array(slide.read_region(path,0,(1936,1216)).convert("RGB"))

        ratio_x = 1936/(224*3)
        ratio_y = 1216/(224*2)
        idx = info[2]
        c1 = (int(info[0][0]),int(info[0][1]))
        c2 = (int(info[1][0]),int(info[1][1]))
        if idx == 0:
            extra_x = 0
            extra_y = 0

        elif idx == 1:
            extra_x = 224
            extra_y = 0

        elif idx == 2:
            extra_x = 224*2
            extra_y = 0

        elif idx == 3:
            extra_x = 0
            extra_y = 224

        elif idx == 4:
            extra_x = 224
            extra_y = 224

        elif idx == 5:
            extra_x = 224*2
            extra_y = 224

        else:
            print("error!")

        x1 = int((info[0][0] + extra_x)*ratio_x)
        y1 = int((info[0][1] + extra_y)*ratio_y)
        x2 = int((info[1][0] + extra_x)*ratio_x)
        y2 = int((info[1][1] + extra_y)*ratio_y)

        c1 = (x1,y1)
        c2 = (x2,y2)

        if int(info[5]) == 0:
            img_ori = cv2.rectangle(img_ori,c1,c2,(0,255,0),5)
        else:
            img_ori = cv2.rectangle(img_ori,c1,c2,(255,0,0),5)

        plt.figure(figsize=(10,10))
        plt.imshow(img_ori)
        plt.show()
# Out:
# 0.718952476978302 (30976, 10944)
# 0.7117516845464706 (25168, 13376)
# 0.7094864845275879 (46464, 34048)
# 0.6928487569093704 (3872, 9728)
# 0.6906759142875671 (19360, 43776)
# 0.6882061064243317 (15488, 40128)
# 0.6853956282138824 (5808, 12160)
# 0.6840447187423706 (29040, 30400)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-d3dd5a75e6dc> in <module>
#      52         plt.figure(figsize=(10,10))
#      53         plt.imshow(img_ori)
# ---> 54         plt.show()
#
# /opt/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ...

# %%
for uid in final_results.keys():
    print (uid)
    for i in final_results[uid]["sort_list_LSIL"][0:10]+final_results[uid]["sort_list_HSIL"][0:10]:
        path,info,prob = i
        print(prob)
        img_ori = cv2.imread(path)
        img_ori = cv2.cvtColor(img_ori, cv2.COLOR_BGR2RGB)

        ratio_x = 1936/(224*3)
        ratio_y = 1216/(224*2)
        idx = info[2]
        c1 = (int(info[0][0]),int(info[0][1]))
        c2 = (int(info[1][0]),int(info[1][1]))
        if idx == 0:
            extra_x = 0
            extra_y = 0

        elif idx == 1:
            extra_x = 224
            extra_y = 0

        elif idx == 2:
            extra_x = 224*2
            extra_y = 0

        elif idx == 3:
            extra_x = 0
            extra_y = 224

        elif idx == 4:
            extra_x = 224
            extra_y = 224

        elif idx == 5:
            extra_x = 224*2
            extra_y = 224

        else:
            print("error!")

        x1 = int((info[0][0] + extra_x)*ratio_x)
        y1 = int((info[0][1] + extra_y)*ratio_y)
        x2 = int((info[1][0] + extra_x)*ratio_x)
        y2 = int((info[1][1] + extra_y)*ratio_y)

        c1 = (x1,y1)
        c2 = (x2,y2)

        if int(info[5]) == 0:
            img_ori = cv2.rectangle(img_ori,c1,c2,(0,255,0),5)
        else:
            img_ori = cv2.rectangle(img_ori,c1,c2,(255,0,0),5)

        plt.figure(figsize=(10,10))
        plt.imshow(img_ori)
        plt.show()
# Out:
# 2020-07-21-094821
# 0.7530249059200287
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-dd9f5d434b05> in <module>
#       4         path,info,prob = i
#       5         print(prob)
# ----> 6         img_ori = cv2.imread(path)
#       7         img_ori = cv2.cvtColor(img_ori, cv2.COLOR_BGR2RGB)
#       8
#
# TypeError: bad argument type for built-in operation
